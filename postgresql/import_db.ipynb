# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# 定义 PostgreSQL 连接信息
DATABASE_URI = ""

# %%
# 定义 CSV 文件路径
CSV_FILE_PATH = r''

# %%
# 读取 CSV 文件到 Pandas DataFrame
df = pd.read_csv(CSV_FILE_PATH)

# %%
# 创建 PostgreSQL 数据库引擎
engine = create_engine(DATABASE_URI)

# %%
# 将 DataFrame 写入 PostgreSQL 数据库
df.to_sql('QA', engine, if_exists='replace', index=False)

print("CSV 文件成功导入 PostgreSQL 数据库。")
# Out:
# CSV 文件成功导入 PostgreSQL 数据库。
# c:\Users\T14 Gen 3\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\sql.py:1961: SAWarning: Did not recognize type 'vector' of column 'embedding'
#   self.meta.reflect(bind=self.con, only=[table_name], schema=schema)
